# %% [markdown]
# # Logistic Regression
#
# This is my mini-project using Logistic Regression to accurately predict the survival outcomes of Titanic passengers based on their characteristics. This is a binary classification problem where the target variable is binary (survived or did not survive). Understanding which passenger characteristics were associated with higher survival rates provides valuable insights into the historical patterns during this tragedy and demonstrates the application of statistical learning methods to real-world historical data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# 1. Load dataset
df = pd.read_csv('titanic_modified_dataset.csv', index_col = 'PassengerId') # Choose PassengerID as index

print(df.head(3))

df = df.to_numpy().astype(np.float64)
m = df.shape[0]

X = df[:, :-1]
y = df[:, -1]

X_bias = np.concatenate((np.ones((m, 1)), X), axis = 1)
print(X_bias)
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# PassengerId
# 1                 3    0  22.0      1      0   7.2500         0      0
# 2                 1    1  38.0      1      0  71.2833         1      1
# 3                 3    1  26.0      0      0   7.9250         0      2
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# [[ 1.      3.      0.     ...  7.25    0.      0.    ]
#  [ 1.      1.      1.     ... 71.2833  1.      1.    ]
#  [ 1.      3.      1.     ...  7.925   0.      2.    ]
#  ...
#  [ 1.      3.      1.     ... 23.45    0.      2.    ]
#  [ 1.      1.      0.     ... 30.      1.      0.    ]
#  [ 1.      3.      0.     ...  7.75    2.      0.    ]]

# %%
# 2. Split Train, Validation, and Test
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X_bias, y,
    test_size = val_size,
    random_state = random_state,
    shuffle = is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size = test_size,
    random_state = random_state,
    shuffle = is_shuffle
)

# 3. Scaling data
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
# 2. Important functions
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def predict(theta, xi):
    z = np.dot(xi, theta)
    return sigmoid(z)

def compute_loss(yi, prediction):
    return -(yi * np.log(prediction) + (1 - yi) * np.log(1 - prediction))

def compute_accuracy(y_true, y_predict_prob, threshold = 0.5):
    y_pred_class = (y_predict_prob >= threshold).astype(int)
    accuracy = np.mean(y_pred_class == y_true)
    return accuracy

# 3. Stochastic logistic regression
def stochastic_logistic_regression(X_train, y_train, X_val, y_val, 
                                   epochs = 10000, learning_rate = 1e-5):
    (m, n) = X_train.shape
    theta = np.zeros(n)
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    
    for epoch in range(epochs):
        train_loss = 0
        
        for i in range(m):
            y_pred = predict(theta, X_train[i])
            error = y_train[i] - y_pred
            theta = theta + learning_rate * error * X_train[i]
            train_loss += compute_loss(y_train[i], y_pred)
        
        avg_train_loss = train_loss / m
        train_losses.append(avg_train_loss)
        
        y_val_pred = predict(theta, X_val)
        val_loss = compute_loss(y_val, y_val_pred)
        avg_val_loss = np.mean(val_loss)
        val_losses.append(avg_val_loss)
        
        train_acc = compute_accuracy(y_train, predict(theta, X_train))
        val_acc = compute_accuracy(y_val, y_val_pred)
        
        train_accuracies.append(train_acc)
        val_accuracies.append(val_acc)
        
        # Print progress
        if (epoch + 1) % 1000 == 0:
            print(f"Epoch {epoch+1:5d}/{epochs} - "
                  f"Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f} - "
                  f"Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")
    
    return theta, train_losses, val_losses, train_accuracies, val_accuracies

# 4. Print answer and plot digram
theta, train_losses, val_losses, train_accs, val_accs = stochastic_logistic_regression(X_train, y_train, X_val, y_val, 100000, 1e-5)


fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel = 'Epoch', ylabel = 'Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel = 'Epoch', ylabel = 'Accuracy')
ax[1, 1].set_title('Validation Accuracy')
# Out:
# Epoch  1000/100000 - Train Loss: 0.4460, Val Loss: 0.5071 - Train Acc: 0.7994, Val Acc: 0.7542
# Epoch  2000/100000 - Train Loss: 0.4230, Val Loss: 0.5074 - Train Acc: 0.8058, Val Acc: 0.7709
# Epoch  3000/100000 - Train Loss: 0.4164, Val Loss: 0.5118 - Train Acc: 0.8122, Val Acc: 0.7765
# Epoch  4000/100000 - Train Loss: 0.4136, Val Loss: 0.5153 - Train Acc: 0.8154, Val Acc: 0.7765
# Epoch  5000/100000 - Train Loss: 0.4124, Val Loss: 0.5179 - Train Acc: 0.8170, Val Acc: 0.7709
# Epoch  6000/100000 - Train Loss: 0.4117, Val Loss: 0.5198 - Train Acc: 0.8170, Val Acc: 0.7654
# Epoch  7000/100000 - Train Loss: 0.4113, Val Loss: 0.5211 - Train Acc: 0.8170, Val Acc: 0.7654
# Epoch  8000/100000 - Train Loss: 0.4111, Val Loss: 0.5222 - Train Acc: 0.8170, Val Acc: 0.7654
# Epoch  9000/100000 - Train Loss: 0.4110, Val Loss: 0.5230 - Train Acc: 0.8154, Val Acc: 0.7654
# Epoch 10000/100000 - Train Loss: 0.4110, Val Loss: 0.5236 - Train Acc: 0.8154, Val Acc: 0.7654
# Epoch 11000/100000 - Train Loss: 0.4109, Val Loss: 0.5240 - Train Acc: 0.8170, Val Acc: 0.7654
# Epoch 12000/100000 - Train Loss: 0.4109, Val Loss: 0.5243 - Train Acc: 0.8170, Val Acc: 0.7654
# Epoch 13000/100000 - Train Loss: 0.4109, Val Loss: 0.5246 - Train Acc: 0.8170, Val Acc: 0.7709
# Epoch 14000/100000 - Train Loss: 0.4109, Val Loss: 0.5248 - Train Acc: 0.8170, Val Acc: 0.7709
# Epoch 15000/100000 - Train Loss: 0.4109, Val Loss: 0.5249 - Train Acc: 0.8170, Val Acc: 0.7709
# Epoch 16000/100000 - Train Loss: 0.4109, Val Loss: 0.5251 - Train Acc: 0.8170, Val Acc: 0.7709
# Epoch 17000/100000 - Train Loss: 0.4109, Val Loss: 0.5251 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 18000/100000 - Train Loss: 0.4109, Val Loss: 0.5252 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 19000/100000 - Train Loss: 0.4109, Val Loss: 0.5253 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 20000/100000 - Train Loss: 0.4109, Val Loss: 0.5253 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 21000/100000 - Train Loss: 0.4109, Val Loss: 0.5253 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 22000/100000 - Train Loss: 0.4109, Val Loss: 0.5253 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 23000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 24000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 25000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 26000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 27000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 28000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 29000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 30000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 31000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 32000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 33000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 34000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 35000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 36000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 37000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 38000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 39000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 40000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 41000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 42000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 43000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 44000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 45000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 46000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 47000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 48000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 49000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 50000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 51000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 52000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 53000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 54000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 55000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 56000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 57000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 58000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 59000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 60000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 61000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 62000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 63000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 64000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 65000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 66000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 67000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 68000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 69000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 70000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 71000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 72000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 73000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 74000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 75000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 76000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 77000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 78000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 79000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 80000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 81000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 82000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 83000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 84000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 85000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 86000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 87000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 88000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 89000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 90000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 91000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 92000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 93000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 94000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 95000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 96000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 97000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 98000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 99000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Epoch 100000/100000 - Train Loss: 0.4109, Val Loss: 0.5254 - Train Acc: 0.8170, Val Acc: 0.7765
# Text(0.5, 1.0, 'Validation Accuracy')
